# %%
#import part
import src.make_map_list as mml
import src.dijkstra_route as dijk

# %%
#make map list part
num_node = 8

result = mml.make_map(num_node)
print(result)
# Out:
# {'0': {'pos': (99, 35), 'edges': [('3', 20), ('4', 49)]}, '1': {'pos': (2, 36), 'edges': [('3', 99), ('7', 8)]}, '2': {'pos': (1, 54), 'edges': [('6', 50), ('0', 99)]}, '3': {'pos': (100, 55), 'edges': [('0', 20), ('2', 99)]}, '4': {'pos': (52, 51), 'edges': [('6', 13), ('1', 52)]}, '5': {'pos': (56, 73), 'edges': [('1', 65), ('6', 35)]}, '6': {'pos': (49, 38), 'edges': [('3', 53), ('1', 47)]}, '7': {'pos': (0, 44), 'edges': [('5', 63), ('3', 100)]}}

# %%
print(result.keys())
# Out:
# dict_keys(['0', '1', '2', '3', '4', '5', '6', '7'])

# %%
dijk_ans = dijk.dijkstra(result,'0','7')
print(dijk_ans)
# Out:
# === ダイクストラ法 計算結果 (始点: 0) ===
# ノード 0  | 最小コスト:      0
# -------------------------
# ノード 1  | 最小コスト:    101
# -------------------------
# ノード 2  | 最小コスト:    119
# -------------------------
# ノード 3  | 最小コスト:     20
# -------------------------
# ノード 4  | 最小コスト:     49
# -------------------------
# ノード 5  | 最小コスト:    172
# -------------------------
# ノード 6  | 最小コスト:     62
# -------------------------
# ノード 7  | 最小コスト:    109
# -------------------------
#
# [最短経路]: 0 -> 4 -> 1 -> 7
# ============================================
# ({'0': 0, '1': 101, '2': 119, '3': 20, '4': 49, '5': 172, '6': 62, '7': 109}, {'0': None, '1': '4', '2': '3', '3': '0', '4': '0', '5': '7', '6': '4', '7': '1'}, ['0', '4', '1', '7'])
