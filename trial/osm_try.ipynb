# %%
import matplotlib.pyplot as plt
import random
import osmnx as ox
import pandas as pd

# %%
G = ox.graph_from_place("神奈川県横浜市都筑区",network_type="drive")

# %%
fig, ax = ox.plot_graph(G,show=True,bgcolor="#FFFFFF")

# %%
# ノード作成
nodes = G.nodes()
node_list = list(nodes)

order_nodes = random.sample(node_list,20)
